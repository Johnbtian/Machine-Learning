# %%
import pandas as pd
df=pd.read_csv("Electric_Production.csv",index_col="DATE",parse_dates=True)
df.head()
# Out:
#             IPG2211A2N
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151

# %%
df.rename(columns = {'IPG2211A2N':'cost'}, inplace = True)
df.head()
# Out:
#                cost
# DATE
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151

# %%
df["cost"].plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df["cost"].plot(figsize=(10,6))
df["cost"].rolling(window=5).mean().plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df["Moving_avg"]=df["cost"].rolling(window=5).mean()
df.head(30)
# Out:
#                cost  Moving_avg
# DATE
# 1985-01-01  72.5052         NaN
# 1985-02-01  70.6720         NaN
# 1985-03-01  62.4502         NaN
# 1985-04-01  57.4714         NaN
# 1985-05-01  55.3151    63.68278
# 1985-06-01  58.0904    60.79982
# 1985-07-01  62.6202    59.18946
# 1985-08-01  63.2485    59.34912
# 1985-09-01  60.5846    59.97176
# 1985-10-01  56.3154    60.17182
# 1985-11-01  58.0005    60.15384
# 1985-12-01  68.7145    61.37270
# 1986-01-01  73.3057    63.38414
# 1986-02-01  67.9869    64.86460
# 1986-03-01  62.2221    66.04594
# 1986-04-01  57.0329    65.85242
# 1986-05-01  55.8137    63.27226
# 1986-06-01  59.9005    60.59122
# 1986-07-01  65.7655    60.14694
# 1986-08-01  64.4816    60.59884
# 1986-09-01  61.0005    61.39236
# 1986-10-01  57.5322    61.73606
# 1986-11-01  59.3417    61.62430
# 1986-12-01  68.1354    62.09828
# 1987-01-01  73.8152    63.96500
# 1987-02-01  70.0620    65.77730
# 1987-03-01  65.6100    67.39286
# 1987-04-01  60.1586    67.55624
# ...
